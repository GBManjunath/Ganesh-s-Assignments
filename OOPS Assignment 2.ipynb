# %%
'''
Constructor: 


1.What is a constructor in Python? Explain its purpose and usage.
A constructor in Python is a special method that is automatically called when an object of a class is created. Its purpose is to initialize the attributes of the object and perform any setup or initialization required for the object to function properly. Constructors are defined using the __init__ method in Python classes.

2. Differentiate between a parameterless constructor and a parameterized constructor in Python.

A parameterless constructor is a constructor that takes no parameters. It is defined without any additional parameters inside the __init__ method.

A parameterized constructor, on the other hand, takes one or more parameters in addition to the usual self parameter. These parameters are used to initialize the attributes of the object based on the values provided during object creation.

3. How do you define a constructor in a Python class? Provide an example.

To define a constructor in a Python class, you use the __init__ method. Here's an example:
'''
#4Explain the __init__ method in Python and its role in constructors.

#The __init__ method is a special method in Python classes that serves as the constructor. It is automatically called when an object is created from the class and is used to initialize the object's attributes. The self parameter refers to the instance of the object being created, and any other parameters can be used to pass initial values to the attributes.

#5. In a class named Person, create a constructor that initializes the name and age attributes. Provide an example of creating an object of this class.

 
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

# Creating an object of the Person class
person1 = Person("John", 25)
#6 How can you call a constructor explicitly in Python? Give an example.

#Constructors are automatically called when an object is created, and explicit calls are not common. However, if you have a situation where you need to call a constructor explicitly, you can use the class name followed by parentheses:

 
class MyClass:
    def __init__(self, parameter):
        self.parameter = parameter

# Explicitly calling the constructor
obj = MyClass.__init__(parameter)

#7 What is the significance of the self parameter in Python constructors? Explain with an example.

#The self parameter refers to the instance of the object being created. It allows you to access and modify the object's attributes within the class. Here's an example:

 
class MyClass:
    def __init__(self, parameter):
        self.parameter = parameter

# Creating an object of the MyClass class
obj = MyClass("value")

# Accessing the attribute using the 'self' parameter
print(obj.parameter)  # Output: value

#8 Discuss the concept of default constructors in Python. When are they used?

'''In Python, there is no explicit syntax for a default constructor like in some other programming languages. The __init__ method itself can be considered a default constructor when it takes no additional parameters. Default constructors are used when you don't need to pass any parameters during the object creation.

#9 Create a Python class called Rectangle with a constructor that initializes the width and height attributes. Provide a method to calculate the area of the rectangle.
'''
 
class Rectangle:
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def calculate_area(self):
        return self.width * self.height

# Creating an object of the Rectangle class
rectangle = Rectangle(5, 10)

# Calculating and printing the area
print("Area of the rectangle:", rectangle.calculate_area())
#10 How can you have multiple constructors in a Python class? Explain with an example.

#In Python, you can use default values for parameters to simulate multiple constructors. Here's an example:

 
class MyClass:
    def __init__(self, parameter1, parameter2=0):
        self.parameter1 = parameter1
        self.parameter2 = parameter2

# Creating objects with different constructors
obj1 = MyClass("value1")
obj2 = MyClass("value1", "value2")


#11 What is method overloading, and how is it related to constructors in Python?

#Method overloading refers to the ability to define multiple methods with the same name in a class, but with different parameter lists. In Python, method overloading is not directly supported, but you can achieve similar behavior by using default values for parameters in methods, including constructors.

#12 Explain the use of the super() function in Python constructors. Provide an example.

#The super() function is used to call the constructor of the parent class. This is useful when you want to extend the functionality of a parent class in a child class. Here's an example:

 
class ParentClass:
    def __init__(self, parameter):
        self.parameter = parameter

class ChildClass(ParentClass):
    def __init__(self, parameter, additional_parameter):
        super().__init__(parameter)
        self.additional_parameter = additional_parameter

# Creating an object of the ChildClass
child_obj = ChildClass("value1", "value2")
#13 Create a class called Book with a constructor that initializes the title, author, and published_year attributes. Provide a method to display book details.

 
class Book:
    def __init__(self, title, author, published_year):
        self.title = title
        self.author = author
        self.published_year = published_year

    def display_details(self):
        print(f"Title: {self.title}, Author: {self.author}, Published Year: {self.published_year}")

# Creating an object of the Book class
book = Book("Python Programming", "John Doe", 2022)

# Displaying book details
book.display_details()

#14 Discuss the differences between constructors and regular methods in Python classes.

'''Constructors, such as __init__, are special methods called automatically when an object is created, while regular methods are explicitly called on objects.
Constructors initialize object attributes, while regular methods perform specific actions or computations on the object's data.
Constructors have the self parameter pointing to the instance being created, while regular methods have `

 
15. Explain the role of the self parameter in instance variable initialization within a constructor.

The self parameter in a constructor refers to the instance of the object being created. It is a convention in Python to use self as the first parameter in instance methods, including the constructor. The self parameter allows you to access and modify the object's attributes within the class.

#16 How do you prevent a class from having multiple instances by using constructors in Python? Provide an example.

You can use a class variable to track whether an instance has been created and prevent the creation of multiple instances. Here's an example:

'''
class SingletonClass:
    _instance = None

    def __new__(cls):
        if cls._instance is None:
            cls._instance = super().__new__(cls)
        return cls._instance

# Creating instances of the SingletonClass
obj1 = SingletonClass()
obj2 = SingletonClass()

print(obj1 is obj2)  # Output: True

#17 Create a Python class called Student with a constructor that takes a list of subjects as a parameter and initializes the subjects attribute.

 
class Student:
    def __init__(self, subjects):
        self.subjects = subjects

# Creating an object of the Student class
student = Student(["Math", "Science", "English"])

'''18 What is the purpose of the __del__ method in Python classes, and how does it relate to constructors?

The __del__ method in Python is a special method that is called when an object is about to be destroyed or deleted. It is the opposite of the __init__ method, which is called during object creation. The __del__ method can be used to perform cleanup actions before the object is removed from memory.

19. Explain the use of constructor chaining in Python. Provide a practical example.

Constructor chaining refers to calling one constructor from another within the same class or from a parent class to a child class. This is often done using the super() function. Here's an example:

'''
class ParentClass:
    def __init__(self, parameter):
        self.parameter = parameter

class ChildClass(ParentClass):
    def __init__(self, parameter, additional_parameter):
        super().__init__(parameter)
        self.additional_parameter = additional_parameter

# Creating an object of the ChildClass
child_obj = ChildClass("value1", "value2")
#20 Create a Python class called Car with a default constructor that initializes the make and model attributes. Provide a method to display car information.

 
class Car:
    def __init__(self, make, model):
        self.make = make
        self.model = model

    def display_info(self):
        print(f"Make: {self.make}, Model: {self.model}")

# Creating an object of the Car class with default constructor
car = Car("Toyota", "Camry")

# Displaying car information
car.display_info()

# %%
'''
Inheritance


1. What is inheritance in Python? Explain its significance in object-oriented programming.

Inheritance in Python is a mechanism where a class (subclass/child) inherits properties and behaviors from another class (superclass/parent). It allows the creation of a new class that is a modified version of an existing class, promoting code reuse and creating a hierarchy of classes. Inheritance is a fundamental concept in object-oriented programming as it supports the "is-a" relationship between classes.

2. Differentiate between single inheritance and multiple inheritance in Python. Provide examples for each.

Single Inheritance:

In single inheritance, a class inherits from only one superclass.
'''
 
class Animal:
    def speak(self):
        print("Animal speaks")

class Dog(Animal):
    def bark(self):
        print("Dog barks")

# Example of single inheritance
dog_instance = Dog()
dog_instance.speak()  # Accessing method from the superclass
Multiple Inheritance:

#In multiple inheritance, a class can inherit from more than one superclass.

 
class Flyable:
    def fly(self):
        print("Can fly")

class Bird(Animal, Flyable):
    pass

# Example of multiple inheritance
bird_instance = Bird()
bird_instance.speak()  # Accessing method from the first superclass
bird_instance.fly()    # Accessing method from the second superclass
#3 Create a Python class called Vehicle with attributes color and speed. Then, create a child class called Car that inherits from Vehicle and adds a brand attribute. Provide an example of creating a Car object.

 
class Vehicle:
    def __init__(self, color, speed):
        self.color = color
        self.speed = speed

class Car(Vehicle):
    def __init__(self, color, speed, brand):
        super().__init__(color, speed)
        self.brand = brand

# Example of creating a Car object
car = Car("Red", 60, "Toyota")
#4 Explain the concept of method overriding in inheritance. Provide a practical example.

#Method overriding occurs when a subclass provides a specific implementation for a method that is already defined in its superclass. The overridden method in the subclass takes precedence over the method in the superclass.

 
class Animal:
    def speak(self):
        print("Animal speaks")

class Dog(Animal):
    def speak(self):  # Method overriding
        print("Dog barks")

# Example of method overriding
dog_instance = Dog()
dog_instance.speak()  # Outputs: Dog barks

#6 How can you access the methods and attributes of a parent class from a child class in Python? Give an example.

#You can access the methods and attributes of a parent class in a child class using the super() function.

python
Copy code
class Animal:
    def speak(self):
        print("Animal speaks")

class Dog(Animal):
    def speak(self):
        super().speak()  # Calling the speak method of the parent class
        print("Dog barks")

# Example of accessing parent class method in a child class
dog_instance = Dog()
dog_instance.speak()  
# Outputs:
# Animal speaks
# Dog barks

#6 Discuss the use of the super() function in Python inheritance. When and why is it used? Provide an example.

#The super() function is used to call a method from the parent class in a child class. It is commonly used to invoke the superclass's constructor or methods overridden in the subclass.

 
class Animal:
    def speak(self):
        print("Animal speaks")

class Dog(Animal):
    def speak(self):
        super().speak()  # Calling the speak method of the parent class
        print("Dog barks")

# Example of using super() to call parent class method
dog_instance = Dog()
dog_instance.speak()
#7 Create a Python class called Animal with a method speak(). Then, create child classes Dog and Cat that inherit from Animal and override the speak() method. Provide an example of using these classes.

 
class Animal:
    def speak(self):
        print("Animal speaks")

class Dog(Animal):
    def speak(self):
        print("Dog barks")

class Cat(Animal):
    def speak(self):
        print("Cat meows")

# Example of using Animal, Dog, and Cat classes
dog_instance = Dog()
cat_instance = Cat()

dog_instance.speak()  # Outputs: Dog barks
cat_instance.speak()  # Outputs: Cat meows

#8 Explain the role of the isinstance() function in Python and how it relates to inheritance.

#The isinstance() function is used to check if an object is an instance of a particular class or a tuple of classes. In the context of inheritance, it helps determine if an object is an instance of a specific class or any of its subclasses.

 
class Animal:
    pass

class Dog(Animal):
    pass

dog_instance = Dog()

print(isinstance(dog_instance, Dog))     # Outputs: True
print(isinstance(dog_instance, Animal))  # Outputs: True

#9 What is the purpose of the issubclass() function in Python? Provide an example.

#The issubclass() function checks if a class is a subclass of another class. It helps to determine the relationship between classes in terms of inheritance.

 
class Animal:
    pass

class Dog(Animal):
    pass

print(issubclass(Dog, Animal))  # Outputs: True

#10. Discuss the concept of constructor inheritance in Python. How are constructors inherited in child classes?

#Constructors are inherited in child classes through the use of the super() function. When a child class is created, the __init__ method of the parent class can be called using super().__init__() to initialize attributes inherited from the parent class.

#11. Create a Python class called Shape with a method area() that calculates the area of a shape. Then, create child classes Circle and Rectangle that inherit from Shape and implement the area() method accordingly. Provide an example.

 
from math import pi

class Shape:
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return pi * self.radius ** 2

class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

# Example of using Circle and Rectangle classes
circle_instance = Circle(5)
rectangle_instance = Rectangle(4, 6)

print("Area of Circle:", circle_instance.area())        # Outputs: Area of Circle: 78.53981633974483
print("Area of Rectangle:", rectangle_instance.area())  # Outputs: Area of Rectangle: 24

#12. Explain the use of abstract base classes (ABCs) in Python and how they relate to inheritance. Provide an example using the abc module.

#Abstract base classes (ABCs) are used to define abstract classes and abstract methods. Abstract methods must be implemented by concrete (non-abstract) subclasses. The abc module provides the ABC class and abstractmethod decorator for creating abstract classes and methods.

 
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return pi * self.radius ** 2

# Example of using Circle class
circle_instance = Circle(5)
print("Area of Circle:", circle_instance.area())  # Outputs: Area of Circle: 78.53981633974483

#13 How can you prevent a child class from modifying certain attributes or methods inherited from a parent class in Python?

#In Python, you can make attributes or methods private in the parent class by prefixing them with a double underscore (__). This will make them difficult to modify directly from the child class.

 
class Parent:
    def __init__(self):
        self.__private_attribute = 42

    def __private_method(self):
        print("This is a private method")

class Child(Parent):
    def access_private(self):
        # Accessing private attribute
        print(self.__private_attribute)  # This will raise an AttributeError

        # Accessing private method
        self.__private_method()  # This will raise an AttributeError
#14 Create a Python class called Employee with attributes name and salary. Then, create a child class Manager that inherits from Employee and adds an attribute department. Provide an example.

 
class Employee:
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary

class Manager(Employee):
    def __init__(self, name, salary, department):
        super().__init__(name, salary)
        self.department = department

# Example of using Employee and Manager classes
manager_instance = Manager("John Doe", 60000, "HR")

print("Name:", manager_instance.name)
print("Salary:", manager_instance.salary)
print("Department:", manager_instance.department)

'''15 Discuss the concept of method overloading in Python inheritance. How does it differ from method overriding?

Method overloading in Python is achieved by defining multiple methods with the same name in a class, but with different parameter lists. However, Python does not support traditional method overloading like some other languages. Instead, the last defined method with a specific name and parameters in a class takes precedence.

Method overriding, on the other hand, occurs when a subclass provides a specific implementation for a method that is already defined in its superclass. The overridden method in the subclass takes precedence over the method in the superclass.

16 Explain the purpose of the __init__() method in Python inheritance and how it is utilized in child classes.

The __init__() method in Python is the constructor method, and it is called when an object is created. In inheritance, the __init__() method of the parent class can be called using super().__init__() in the child class. This allows the child class to initialize attributes inherited from the parent class.

17. Create a Python class called Bird with a method fly(). Then, create child classes Eagle and Sparrow that inherit from Bird and implement the fly() method differently. Provide an example of using these classes.
'''
 
class Bird:
    def fly(self):
        pass

class Eagle(Bird):
    def fly(self):
        print("Eagle soars high")

class Sparrow(Bird):
    def fly(self):
        print("Sparrow flits around")

# Example of using Eagle and Sparrow classes
eagle_instance = Eagle()
sparrow_instance = Sparrow()

eagle_instance.fly()    # Outputs: Eagle soars high
sparrow_instance.fly()  # Outputs: Sparrow flits around
'''18 What is the "diamond problem" in multiple inheritance, and how does Python address it?

The "diamond problem" in multiple inheritance occurs when a class inherits from two classes that have a common ancestor. If the common ancestor has methods or attributes, it may lead to ambiguity in the subclass about which method or attribute to use.

Python addresses the "diamond problem" by using a method resolution order (MRO). The MRO defines the order in which base classes are searched when looking for a method or attribute. Python uses the C3 linearization algorithm to determine the MRO, which ensures a consistent and predictable order.

19. Discuss the concept of "is-a" and "has-a" relationships in inheritance, and provide examples of each.

"Is-a" Relationship:
Inheritance typically represents an "is-a" relationship, indicating that a subclass is a specific type of its superclass.
'''
 
class Vehicle:
    pass

class Car(Vehicle):
    pass

car_instance = Car()
isinstance(car_instance, Vehicle)  # True
"Has-a" Relationship:
Composition represents a "has-a" relationship, indicating that a class has another class as part of its structure.

 
class Engine:
    pass

class Car:
    def __init__(self):
        self.engine = Engine()

car_instance = Car()
isinstance(car_instance.engine, Engine)  # True

#20 Create a Python class hierarchy for a university system. Start with a base class Person and create child classes Student and Professor, each with their own attributes and methods. Provide an example of using these classes in a university context.

 
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def display_info(self):
        print(f"Name: {self.name}, Age: {self.age}")

class Student(Person):
    def __init__(self, name, age, student_id):
        super().__init__(name, age)
        self.student_id = student_id

    def display_info(self):
        super().display_info()
        print(f"Student ID: {self.student_id}")

class Professor(Person):
    def __init__(self, name, age, employee_id):
        super().__init__(name, age)
        self.employee_id = employee_id

    def display_info(self):
        super().display_info()
        print(f"Employee ID: {self.employee_id}")

# Example of using Person, Student, and Professor classes

# %%
'''# Encapsulation:

## 1. Explain the concept of encapsulation in Python. What is its role in object-oriented programming?
   - Encapsulation is the bundling of data and methods that operate on the data into a single unit known as a class. It helps in hiding the internal details of an object and allows controlled access to its attributes and methods. Encapsulation is a fundamental concept in object-oriented programming (OOP) that promotes data abstraction, information hiding, and code organization.

## 2. Describe the key principles of encapsulation, including access control and data hiding.
   - Access control ensures that the internal details of a class are not directly accessible from outside. Data hiding involves restricting access to certain details of an object and exposing only what is necessary for the functioning of the class. These principles contribute to the encapsulation of data and behavior within a class.

## 3. How can you achieve encapsulation in Python classes? Provide an example.
   - Encapsulation in Python is achieved by defining attributes as private and providing public methods (getters and setters) to access or modify them.

   ```python
   class Example:
       def __init__(self):
           self.__private_attribute = 42

       def get_private_attribute(self):
           return self.__private_attribute

       def set_private_attribute(self, value):
           self.__private_attribute = value
4. Discuss the difference between public, private, and protected access modifiers in Python.
Public: Accessible from anywhere.
Private (denoted by double underscore __): Accessible only within the class.
Protected (denoted by a single underscore _): Accessible within the class and its subclasses.
5. Create a Python class called Person with a private attribute __name. Provide methods to get and set the name attribute.
python
Copy code
class Person:
    def __init__(self, name):
        self.__name = name

    def get_name(self):
        return self.__name

    def set_name(self, new_name):
        self.__name = new_name
6. Explain the purpose of getter and setter methods in encapsulation. Provide examples.
Getter methods retrieve the value of a private attribute, and setter methods modify its value. They ensure controlled access to the internal state of an object.
python
Copy code
class Example:
    def __init__(self):
        self.__private_attribute = 42

    def get_private_attribute(self):
        return self.__private_attribute

    def set_private_attribute(self, value):
        self.__private_attribute = value
7. What is name mangling in Python, and how does it affect encapsulation?
Name mangling is a mechanism in Python that changes the name of a variable in a way that makes it harder to accidentally override in subclasses. It involves adding a prefix _classname to a variable with a double underscore (__). While not a strict security feature, it helps in avoiding accidental name clashes and promotes encapsulation.
8. Create a Python class called BankAccount with private attributes for the account balance (__balance) and account number (__account_number). Provide methods for depositing and withdrawing money.
python
Copy code
class BankAccount:
    def __init__(self, account_number, initial_balance):
        self.__account_number = account_number
        self.__balance = initial_balance

    def deposit(self, amount):
        self.__balance += amount

    def withdraw(self, amount):
        if amount <= self.__balance:
            self.__balance -= amount
        else:
            print("Insufficient funds.")

    def get_balance(self):
        return self.__balance
9. Discuss the advantages of encapsulation in terms of code maintainability and security.
Encapsulation enhances code maintainability by providing a clear interface for interaction with objects. It prevents unintended external interference and helps in modifying the internal implementation without affecting the external code. It also improves security by restricting direct access to internal details.
10. How can you access private attributes in Python? Provide an example demonstrating the use of name mangling.
python
Copy code
- Private attributes can be accessed using name mangling by prefixing them with `_classname`.

```python
class Example:
    def __init__(self):
        self.__private_attribute = 42

obj = Example()
print(obj._Example__private_attribute)
```
11. Create a Python class hierarchy for a school system, including classes for students, teachers, and courses, and implement encapsulation principles to protect sensitive information.
python
Copy code
```python
class Person:
    def __init__(self, name, age):
        self.__name = name
        self.__age = age

class Student(Person):
    def __init__(self, name, age, student_id):
        super().__init__(name, age)
        self.__student_id = student_id

class Teacher(Person):
    def __init__(self, name, age, employee_id):
        super().__init__(name, age)
        self.__employee_id = employee_id

class Course:
    def __init__(self, course_name, course_code):
        self.__course_name = course_name
        self.__course_code = course_code
```
12. Explain the concept of property decorators in Python and how they relate to encapsulation.
python
Copy code
- Property decorators in Python allow getter and setter methods to be defined as properties. They provide a cleaner syntax for encapsulation.

```python
class Example:
    def __init__(self):
        self._value = 42

    @property
    def value(self):
        return self._value

    @value.setter
    def value(self, new_value):
        self._value = new_value
```
13. What is data hiding, and why is it important in encapsulation? Provide examples.
vbnet
Copy code
- Data hiding involves restricting access to certain attributes to prevent direct modification. It helps in maintaining the integrity of the object's internal state. Example:

```python
class Example:
    def __init__(self):
        self.__hidden_attribute = 42
```
14. Create a Python class called Employee with private attributes for salary (__salary) and employee ID (__employee_id). Provide a method to calculate yearly bonuses.
python
Copy code
```python
class Employee:
    def __init__(self, employee_id, salary):
        self.__employee_id = employee_id
        self.__salary = salary

    def calculate_bonus(self):
        return 0.1 * self.__salary  # Example calculation, modify as needed
```
15. Discuss the use of accessors and mutators in encapsulation. How do they help maintain control over attribute access?
scss
Copy code
- Accessors (getters) provide controlled access to private attributes, and mutators (setters) allow controlled modification. They help enforce rules and validation, maintaining control over how attributes are accessed and modified.
16. What are the potential drawbacks or disadvantages of using encapsulation in Python?
vbnet
Copy code
- Overusing encapsulation can lead to complex class hierarchies. It may also introduce additional overhead due to the need for getter and setter methods. Striking the right balance is crucial.
'''17. Create a Python class for a library system that encapsulates book information, including titles, authors, and availability status.
python
Copy code
```python
class Book:
    def __init__(self, title, author, availability):
        self.__title = title
        self.__author = author
        self.__availability = availability

    def get_title(self):
        return self.__title

    def get_author(self):
        return self.__author

    def is_available(self):
        return self.__availability
'''```
18. Explain how encapsulation enhances code reusability and modularity in Python programs.
kotlin
Copy code
- Encapsulation helps in creating modular and reusable code by encapsulating the internal details within a class. Changes to the internal implementation do not affect external code that interacts with the class through its public interface.
19. Describe the concept of information hiding in encapsulation. Why is it essential in software development?
kotlin
Copy code
- Information hiding in encapsulation involves concealing the internal details of an object and exposing only what is necessary for its usage. It is essential for software development to prevent unintended interference, enhance security, and facilitate maintenance and updates without affecting external code.

'''
#20. Create a Python class called Customer with private attributes for customer details like name, address, and contact information. Implement encapsulation to ensure data integrity and security.
#python
'''
class Customer:
    def __init__(self, name, address, contact_info):
        self.__name = name
        self.__address = address
        self.__contact_info = contact_info

    def get_name(self):
        return self.__name

    def get_address(self):
        return self.__address

    def get_contact_info(self):
        return self.__contact_info
    
'''

# %%
'''# Polymorphism:

## 1. What is polymorphism in Python? Explain how it is related to object-oriented programming.
   - Polymorphism in Python refers to the ability of objects to take on multiple forms. It allows objects of different classes to be treated as objects of a common base class. This concept is crucial in object-oriented programming (OOP) as it enables code flexibility and reusability by allowing a single interface to represent various types of objects.

## 2. Describe the difference between compile-time polymorphism and runtime polymorphism in Python.
   - Compile-time polymorphism, also known as method overloading, involves having multiple methods with the same name but different parameters. Runtime polymorphism, or method overriding, occurs when a method in a child class has the same name and signature as a method in its parent class. The appropriate method is determined during runtime based on the actual object type.

## 3. Create a Python class hierarchy for shapes (e.g., circle, square, triangle) and demonstrate polymorphism through a common method, such as `calculate_area()`.
   ```python
   class Shape:
       def calculate_area(self):
           pass

   class Circle(Shape):
       def calculate_area(self, radius):
           return 3.14 * radius**2

   class Square(Shape):
       def calculate_area(self, side):
           return side**2

   class Triangle(Shape):
       def calculate_area(self, base, height):
           return 0.5 * base * height
4. Explain the concept of method overriding in polymorphism. Provide an example.
Method overriding occurs when a child class provides a specific implementation for a method that is already defined in its parent class. This allows objects of the child class to use the overridden method instead of the one in the parent class.
python
Copy code
class Parent:
    def my_method(self):
        print("Parent method")

class Child(Parent):
    def my_method(self):
        print("Child method")

obj = Child()
obj.my_method()  # Output: Child method
5. How is polymorphism different from method overloading in Python? Provide examples for both.
Polymorphism involves having a single interface (e.g., method name) that can represent different types, while method overloading is having multiple methods with the same name but different parameters.
python
Copy code
# Polymorphism example
class Animal:
    def speak(self):
        pass

class Dog(Animal):
    def speak(self):
        print("Woof")

class Cat(Animal):
    def speak(self):
        print("Meow")

# Method overloading example
class Calculator:
    def add(self, a, b):
        return a + b

    def add(self, a, b, c):
        return a + b + c
6. Create a Python class called Animal with a method speak(). Then, create child classes like Dog, Cat, and Bird, each with their own speak() method. Demonstrate polymorphism by calling the speak() method on objects of different subclasses.
python
Copy code
class Animal:
    def speak(self):
        pass

class Dog(Animal):
    def speak(self):
        return "Woof"

class Cat(Animal):
    def speak(self):
        return "Meow"

class Bird(Animal):
    def speak(self):
        return "Tweet"

# Polymorphic usage
dog = Dog()
cat = Cat()
bird = Bird()

print(dog.speak())  # Output: Woof
print(cat.speak())  # Output: Meow
print(bird.speak())  # Output: Tweet
7. Discuss the use of abstract methods and classes in achieving polymorphism in Python. Provide an example using the abc module.
python
Copy code
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def calculate_area(self):
        pass

class Circle(Shape):
    def calculate_area(self, radius):
        return 3.14 * radius**2
8. Create a Python class hierarchy for a vehicle system (e.g., car, bicycle, boat) and implement a polymorphic start() method that prints a message specific to each vehicle type.
python
Copy code
class Vehicle:
    def start(self):
        pass

class Car(Vehicle):
    def start(self):
        return "Car started"

class Bicycle(Vehicle):
    def start(self):
        return "Bicycle started"

class Boat(Vehicle):
    def start(self):
        return "Boat started"
9. Explain the significance of the isinstance() and issubclass() functions in Python polymorphism.
isinstance(object, class) checks if an object is an instance of a particular class. issubclass(subclass, class) checks if a class is a subclass of another class. These functions are crucial for determining the type of objects during runtime, supporting polymorphic behavior.
10. What is the role of the @abstractmethod decorator in achieving polymorphism in Python? Provide an example.
kotlin
Copy code
- The `@abstractmethod` decorator is used to define abstract methods in abstract classes, ensuring that child classes provide a concrete implementation for these methods.

```python
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def calculate_area(self):
        pass

class Circle(Shape):
    def calculate_area(self, radius):
        return 3.14 * radius**2
```
11. Create a Python class called Shape with a polymorphic method area() that calculates the area of different shapes (e.g., circle, rectangle, triangle).
python
Copy code
```python
class Shape:
    def area(self):
        pass

class Circle(Shape):
    def area(self, radius):
        return 3.14 * radius**2

class Rectangle(Shape):
    def area(self, length, width):
        return length * width

class Triangle(Shape):
    def area(self, base, height):
        return 0.5 * base * height
```
12. Discuss the benefits of polymorphism in terms of code reusability and flexibility in Python programs.
vbnet
Copy code
- Polymorphism enhances code reusability by allowing a single interface to represent different types of objects. It also increases flexibility as new classes can be added without modifying existing code, and code adapts dynamically to different object types during runtime.
13. Explain the use of the super() function in Python polymorphism. How does it help call methods of parent classes?
vbnet
Copy code
- The `super()` function is used to call methods from the parent class in a child class. It helps in achieving method overriding and allows the child class to extend or modify the behavior of the parent class method.
14. Create a Python class hierarchy for a banking system with various account types (e.g., savings, checking, credit card) and demonstrate polymorphism by implementing a common withdraw() method.
python
Copy code
```python
class Account:
    def withdraw(self, amount):
        pass

class SavingsAccount(Account):
    def withdraw(self, amount):
        return f"Withdrawal from savings account: ${amount}"

class CheckingAccount(Account):
    def withdraw(self, amount):
        return f"Withdrawal from checking account: ${amount}"

class CreditCardAccount(Account):
    def withdraw(self, amount):
        return f"Withdrawal from credit card account: ${amount}"
```
15. Describe the concept of operator overloading in Python and how it relates to polymorphism. Provide examples using operators like + and *.
python
Copy code
- Operator overloading allows custom behavior for standard operators. It is related to polymorphism as it enables different classes to define their own implementation of operators.

```python
class ComplexNumber:
    def __init__(self, real, imaginary):
        self.real = real
        self.imaginary = imaginary

    def __add__(self, other):
        return ComplexNumber(self.real + other.real, self.imaginary + other.imaginary)

    def __mul__(self, other):
        real_part = self.real * other.real - self.imaginary * other.imaginary
        imag_part = self.real * other.imaginary + self.imaginary * other.real
        return ComplexNumber(real_part, imag_part)

num1 = ComplexNumber(1, 2)
num2 = ComplexNumber(2, 3)

result_add = num1 + num2  # Operator overloading for '+'
result_mul = num1 * num2  # Operator overloading for '*'
```
16. What is dynamic polymorphism, and how is it achieved in Python?
vbnet
Copy code
- Dynamic polymorphism, also known as runtime polymorphism, occurs when the correct method to execute is determined during runtime based on the actual object type. In Python, it is achieved through method overriding and the use of the `super()` function.
17. Create a Python class hierarchy for employees in a company (e.g., manager, developer, designer) and implement polymorphism through a common calculate_salary() method.
python
Copy code
```python
class Employee:
    def calculate_salary(self):
        pass

class Manager(Employee):
    def calculate_salary(self):
        return "Salary calculated for a manager"

class Developer(Employee):
    def calculate_salary(self):
        return "Salary calculated for a developer"

class Designer(Employee):
    def calculate_salary(self):
        return "Salary calculated for a designer"
```
18. Discuss the concept of function pointers and how they can be used to achieve polymorphism in Python.
vbnet
Copy code
- In Python, there is no explicit concept of function pointers like in some other languages. However, polymorphism is achieved through dynamic typing and the ability to pass functions as arguments or assign them to variables.
19. Explain the role of interfaces and abstract classes in polymorphism, drawing comparisons between them.
csharp
Copy code
- In Python, interfaces are not explicitly defined. Abstract classes, on the other hand, can have both abstract methods (methods without implementation) and concrete methods. Abstract classes serve as a blueprint for other classes, while interfaces define a contract that implementing classes must adhere to.
20. Create a Python class for a zoo simulation, demonstrating polymorphism with different animal types (e.g., lion, elephant, giraffe).
python
Copy code
```python
class Animal:
    def make_sound(self):
        pass

class Lion(Animal):
    def make_sound(self):
        return "Roar"

class Elephant(Animal):
    def make_sound(self):
        return "Trumpet"

class Giraffe(Animal):
    def make_sound(self):
        return "Hum"
```
'''

# %%
'''Abstraction
# Question 1
# Abstraction in Python is the process of simplifying complex systems by modeling classes based on essential properties and behaviors. In Object-Oriented Programming (OOP), abstraction allows the creation of abstract classes with common interfaces, emphasizing what an object does rather than how it achieves it.

# Question 2
# Benefits of Abstraction:
# - Code Organization: Abstraction organizes code into modular, manageable components.
# - Complexity Reduction: It simplifies system understanding by exposing essential features and hiding implementation details.

# Question 3
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def calculate_area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def calculate_area(self):
        return 3.14 * self.radius * self.radius

class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def calculate_area(self):
        return self.length * self.width

# Example usage:
circle = Circle(5)
print("Circle Area:", circle.calculate_area())

rectangle = Rectangle(4, 6)
print("Rectangle Area:", rectangle.calculate_area())

# Question 4
# Abstract Classes with abc Module
from abc import ABC, abstractmethod

class MyAbstractClass(ABC):
    @abstractmethod
    def my_abstract_method(self):
        pass

# Question 5
# Abstract Classes vs. Regular Classes:
# Abstract classes cannot be instantiated and may contain abstract methods. Regular classes can be instantiated, and all methods have concrete implementations. Abstract classes enforce a common interface, useful for creating a blueprint for derived classes.

# Question 6
# Abstraction in Bank Account Class
class BankAccount:
    def __init__(self, initial_balance):
        self._balance = initial_balance

    def deposit(self, amount):
        self._balance += amount

    def withdraw(self, amount):
        self._balance -= amount

    def get_balance(self):
        return self._balance

# Question 7
# Discuss the concept of interface classes in Python and their role in achieving abstraction.
# Interface classes in Python do not have a specific keyword. They are considered as classes containing only abstract methods, defining a contract for implementing classes.

# Question 8
# Create a Python class hierarchy for animals and implement abstraction by defining common methods (e.g., eat(), sleep()) in an abstract base class.
from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    def eat(self):
        pass

    @abstractmethod
    def sleep(self):
        pass

# Question 9
# Explain the significance of encapsulation in achieving abstraction. Provide examples.
# Encapsulation involves bundling data and methods that operate on the data within a single unit (class). It enhances abstraction by hiding the internal implementation details and exposing only necessary functionalities.

# Question 10
# What is the purpose of abstract methods, and how do they enforce abstraction in Python classes?
# Abstract methods in Python enforce abstraction by ensuring that derived classes provide concrete implementations for these methods. They define a common interface that subclasses must follow.

# Question 11
# Create a Python class for a vehicle system and demonstrate abstraction by defining common methods (e.g., start(), stop()) in an abstract base class.
from abc import ABC, abstractmethod

class Vehicle(ABC):
    @abstractmethod
    def start(self):
        pass

    @abstractmethod
    def stop(self):
        pass

# Question 12
# Describe the use of abstract properties in Python and how they can be employed in abstract classes.
# Abstract properties can be defined using the @property decorator in abstract classes. They enforce that concrete subclasses provide a property with a specific name.

# Question 13
# Create a Python class hierarchy for employees in a company (e.g., manager, developer, designer) and implement abstraction by defining a common get_salary() method.
from abc import ABC, abstractmethod

class Employee(ABC):
    @abstractmethod
    def get_salary(self):
        pass

class Manager(Employee):
    def get_salary(self):
        return 80000

class Developer(Employee):
    def get_salary(self):
        return 60000

# Question 14
# Discuss the differences between abstract classes and concrete classes in Python, including their instantiation.
# - Abstract classes cannot be instantiated.
# - Concrete classes can be instantiated.
# - Abstract classes may contain abstract methods, while concrete classes provide concrete implementations for all methods.

# Question 15
# Explain the concept of abstract data types (ADTs) and their role in achieving abstraction in Python.
# Abstract Data Types (ADTs) are high-level descriptions of data structures or objects that specify their behavior without detailing the implementation. Abstraction in Python helps in creating ADTs by encapsulating data and methods.

# Question 16
# Create a Python class for a computer system, demonstrating abstraction by defining common methods (e.g., power_on(), shutdown()) in an abstract base class.
from abc import ABC, abstractmethod

class ComputerSystem(ABC):
    @abstractmethod
    def power_on(self):
        pass

    @abstractmethod
    def shutdown(self):
        pass

# Question 17
# Discuss the benefits of using abstraction in large-scale software development projects.
# - Eases maintenance and updates.
# - Enhances code readability and understandability.
# - Facilitates collaboration among developers.

# Question 18
# Explain how abstraction enhances code reusability and modularity in Python programs.
# Abstraction allows developers to create modular and reusable components. Abstract classes and interfaces define clear contracts that can be adhered to by different implementations.

# Question 19
# Create a Python class for a library system, implementing abstraction by defining common methods (e.g., add_book(), borrow_book()) in an abstract base class.
from abc import ABC, abstractmethod

class LibrarySystem(ABC):
    @abstractmethod
    def add_book(self):
        pass

    @abstractmethod
    def borrow_book(self):
        pass

# Question 20
# Describe the concept of method abstraction in Python and how it relates to polymorphism.
# Method abstraction in Python involves creating abstract methods in a base class that are implemented differently in derived classes. This relates to polymorphism, where objects of different classes can be used interchangeably if they adhere to a common interface.
'''

# %%
'''


# Question 1
# Composition in Python involves building complex objects by combining simpler ones. It is achieved by creating instances of other classes within a class, allowing for a "has-a" relationship between the classes.

# Question 2
# Inheritance creates an "is-a" relationship, while composition establishes a "has-a" relationship. Composition is often favored for its flexibility and avoiding issues like the diamond problem.

# Question 3
class Author:
    def __init__(self, name, birthdate):
        self.name = name
        self.birthdate = birthdate

class Book:
    def __init__(self, title, author):
        self.title = title
        self.author = author

# Example usage:
author = Author("John Doe", "January 1, 1980")
book = Book("Python Basics", author)
print("Book Title:", book.title)
print("Author:", book.author.name)

# Question 4
# Benefits of Composition:
# - Code Flexibility: Allows for dynamic changes in the behavior of composed objects.
# - Reusability: Promotes reusing smaller, independent components.

# Question 5
# Composition in Python is implemented by creating instances of other classes within a class. Example:
class Engine:
    pass

class Car:
    def __init__(self):
        self.engine = Engine()

# Question 6
# Python class hierarchy for a music player system using composition:
class Song:
    pass

class Playlist:
    def __init__(self):
        self.songs = [Song()]

# Question 7
# "Has-a" Relationships in Composition:
# Composition models relationships where one object "has-a" part of another object, creating a modular and flexible design.

# Question 8
# Python class for a computer system using composition:
class CPU:
    pass

class RAM:
    pass

class Storage:
    pass

class Computer:
    def __init__(self):
        self.cpu = CPU()
        self.ram = RAM()
        self.storage = Storage()

# Question 9
# Delegation in Composition:
# Delegation involves one object relying on another to perform a specific action. It simplifies the design by distributing responsibilities.

# Question 10
# Python class for a car using composition:
class Engine:
    pass

class Wheels:
    pass

class Transmission:
    pass

class Car:
    def __init__(self):
        self.engine = Engine()
        self.wheels = Wheels()
        self.transmission = Transmission()

# Question 11
# Encapsulation in Composition:
# Encapsulation involves hiding the details of composed objects by exposing only necessary functionalities in the containing class.

# Question 12
# Python class for a university course using composition:
class Student:
    pass

class Instructor:
    pass

class Course:
    def __init__(self):
        self.students = [Student()]
        self.instructors = [Instructor()]

# Question 13
# Challenges and Drawbacks of Composition:
# - Increased Complexity: Managing multiple components may become complex.
# - Tight Coupling: Objects can become tightly coupled, reducing flexibility.

# Question 14
# Python class hierarchy for a restaurant system using composition:
class Dish:
    pass

class Ingredient:
    pass

class Menu:
    def __init__(self):
        self.dishes = [Dish()]
        self.ingredients = [Ingredient()]

# Question 15
# Composition enhances code maintainability and modularity by promoting the creation of independent and reusable components.

# Question 16
# Python class for a computer game character using composition:
class Weapon:
    pass

class Armor:
    pass

class Inventory:
    pass

class Character:
    def __init__(self):
        self.weapon = Weapon()
        self.armor = Armor()
        self.inventory = Inventory()

# Question 17
# Aggregation in Composition:
# Aggregation is a specific form of composition where the composed objects have independent lifecycles.

# Question 18
# Python class for a house using composition:
class Room:
    pass

class Furniture:
    pass

class Appliance:
    pass

class House:
    def __init__(self):
        self.rooms = [Room()]
        self.furniture = [Furniture()]
        self.appliances = [Appliance()]

# Question 19
# Achieving Flexibility in Composed Objects:
# Flexibility can be achieved by designing classes to allow dynamic replacement or modification of components at runtime.

# Question 20
# Python class for a social media application using composition:
class User:
    pass

class Post:
    pass

class Comment:
    pass

class SocialMediaApp:
    def __init__(self):
        self.users = [User()]
        self.posts = [Post()]
        self.comments = [Comment()]


'''
